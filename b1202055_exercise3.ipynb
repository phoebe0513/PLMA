# %%
import copy
a={'姓名':'賴宏瑋','性別':'男','作業分數':[95,100,90]}
b={'學號':'M1129020'}
c={**b, **a}
d=copy.deepcopy(c)
c['作業分數'][1]=80
d['姓名']='許珈綺'
d['性別']='女'
e=c.pop('作業分數')
length1=len(e)
avg1=sum(e)/length1
f=d.pop('作業分數')
length2=len(f)
avg2=sum(f)/length2
print(avg1)
print(c)
print(avg2)
print(d)
# Out:
# 88.33333333333333
# {'學號': 'M1129020', '姓名': '賴宏瑋', '性別': '男'}
# 95.0
# {'學號': 'M1129020', '姓名': '許珈綺', '性別': '女'}

# %%
list1=[100,50,45,60,90,95,80,50]
list2=[88]
a=list2+list1
a[2:5]=[70,50]
a.remove(50)
b=a.pop(0)
c=a.pop()
d=b+c
print(d)
# Out:
# 138

# %%
a=347//3
print(a)
b=347%3
print(b)
c=a**b
print(c)
# Out:
# 115
# 2
# 13225
