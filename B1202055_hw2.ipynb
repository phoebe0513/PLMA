# %%
a='C,B,A'
b= ['F','G','H']
str1=a.split(',')
str2=str1+b
str2[0]=('K')
c=str2.pop(2)
print(c)
c=list(str2)
del c[1:4]
c.extend('U')
print(c)
# Out:
# A
# ['K', 'H', 'U']

# %%
a=input('請輸入一個八位數字')
print(a[4])
# Out:
# 請輸入一個八位數字12345678
# 5

# %%
a='My ID is B1202055'
b=a.split(' ')
print(len(b))
c=a[9:]
print(len(c))
# Out:
# 4
# 8

# %%
a="I'm a student"
a.split(' ')
a[2].split("/'")
print(str(a[2]))
# Out:
# m
