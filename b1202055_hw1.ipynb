# %%
print("I'm a student")
# Out:
# I'm a student

# %%
a = int(input("輸入x1:"))
b = int(input("輸入x2:"))
c = int(input("輸入y1:"))
d = int(input("輸入y2:"))


b = b-a
b = b*b
d = d-c
d = d*d
print((b+d)**0.5)
# Out:
# 輸入x1:3
# 輸入x2:2
# 輸入y1:5
# 輸入y2:8
# 3.1622776601683795

# %%
a = int(input("輸入身高(單位：公分)："))
b = int(input("輸入體重(單位：公斤)："))

a/=100
BMI = b/(a*a)
print(BMI)
# Out:
# 輸入身高(單位：公斤)：160
# 輸入體重(單位：公分)：50
# 19.531249999999996
